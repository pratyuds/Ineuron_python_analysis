# %%
import pandas as pd

# %% [markdown]
# # 1. Read this dataset in pandas , mysql and mongodb

# %% [markdown]
# ### using pandas

# %%
fitbit  = pd.read_csv('C:/Users/praty/PycharmProjects/datasets/FitBit data.csv')

# %%
fitbit
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366    3/25/2016       11004       7.110000         7.110000
# 1    1503960366    3/26/2016       17609      11.550000        11.550000
# 2    1503960366    3/27/2016       12736       8.530000         8.530000
# 3    1503960366    3/28/2016       13231       8.930000         8.930000
# 4    1503960366    3/29/2016       12041       7.850000         7.850000
# ..          ...          ...         ...            ...              ...
# 452  8877689391     4/8/2016       23014      20.389999        20.389999
# 453  8877689391     4/9/2016       16470       8.070000         8.070000
# 454  8877689391    4/10/2016       28497      27.530001        27.530001
# 455  8877689391    4/11/2016       10622       8.060000         8.060000
# 456  8877689391    4/12/2016        2350       1.780000         1.780000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# ...

# %% [markdown]
# ### using MongoDB

# %%
import pymongo

client = pymongo.MongoClient("mongodb+srv://ineuron_pratyu:Chahit1117@pratyusha.dc3s9sa.mongodb.net/?retryWrites=true&w=majority")
db = client.test

# %%
fitbit_json=fitbit.to_json("C:/Users/praty/PycharmProjects/datasets/fitbit_json.json")

# %%
import json

# %%
database = client['fitbit']
collection = database["fitbit_dataset"]
with open("C:/Users/praty/PycharmProjects/datasets/fitbit_json.json") as file:
    file_data = json.load(file)
    collection.insert_many([file_data])

# %% [markdown]
# ### using SQL

# %%
from sqlalchemy import create_engine
engine = create_engine('mysql+pymysql://root:Chahit@1117@localhost/fitbit')

fitbit.to_sql('fitbit_data', con=engine, index=False)

# %% [markdown]
# # 3. convert all the dates avaible in dataset to timestamp format in pandas and in sql you to convert it in date format

# %% [markdown]
# ### using pandas

# %%
fitbit.columns
# Out:
# Index(['Id', 'ActivityDate', 'TotalSteps', 'TotalDistance', 'TrackerDistance',
#        'LoggedActivitiesDistance', 'VeryActiveDistance',
#        'ModeratelyActiveDistance', 'LightActiveDistance',
#        'SedentaryActiveDistance', 'VeryActiveMinutes', 'FairlyActiveMinutes',
#        'LightlyActiveMinutes', 'SedentaryMinutes', 'Calories'],
#       dtype='object')

# %%
fitbit['ActivityDate'] = pd.to_datetime(fitbit['ActivityDate'])

# %%
fitbit.dtypes
# Out:
# Id                                   int64
# ActivityDate                datetime64[ns]
# TotalSteps                           int64
# TotalDistance                      float64
# TrackerDistance                    float64
# LoggedActivitiesDistance           float64
# VeryActiveDistance                 float64
# ModeratelyActiveDistance           float64
# LightActiveDistance                float64
# SedentaryActiveDistance            float64
# VeryActiveMinutes                    int64
# FairlyActiveMinutes                  int64
# LightlyActiveMinutes                 int64
# SedentaryMinutes                     int64
# Calories                             int64
# dtype: object

# %% [markdown]
# ### using SQL

# %%
import mysql.connector as conn

mydb = conn.connect(host = "localhost",user = "root",password="Chahit@1117",db ="fitbit")
cursor = mydb.cursor()
cursor.execute("set session sql_mode='' ")
cursor.execute("ALTER TABLE fitbit_data MODIFY COLUMN ActivityDate DATETIME NOT NULL;")

# %%
l =[]
for i in cursor.fetchall():
    l.append(i)

# %%
l
# Out:
# []

# %% [markdown]
# # 4 . Find out in this data that how many unique id's we have

# %%
len(pd.unique(fitbit['Id']))
# Out:
# 35

# %% [markdown]
# # 5 . which id is one of the active id that you have in whole dataset

# %%
fitbit['Id'].value_counts().head(1)
# Out:
# 4020332650    32
# Name: Id, dtype: int64

# %% [markdown]
# # 6 . Find out who is the laziest person id that we have in dataset

# %%
fitbit['Id'].value_counts().tail(1)
# Out:
# 4388161847    8
# Name: Id, dtype: int64

# %% [markdown]
# # 7 . how many of them have not logged there activity find out in terms of number of ids

# %%
low = fitbit.groupby('Id')['TotalSteps'].sum()

# %%
low = low.to_frame(name = 'count').reset_index()

# %%
low
# Out:
#             Id   count
# 0   1503960366  221170
# 1   1624580081   80299
# 2   1644430081   92748
# 3   1844505072   43687
# 4   1927972279   26170
# 5   2022484408  146099
# 6   2026352035   40713
# 7   2320127002   37661
# 8   2347167796  147001
# 9   2873212765   79639
# 10  2891001357    6189
# 11  3372868164   61275
# 12  3977333714  103967
# 13  4020332650  184851
# 14  4057192912   60391
# 15  4319703577   93847
# 16  4388161847       0
# 17  4445114986   64396
# 18  4558609924   69423
# 19  4702921684  119151
# 20  5553957443  100257
# 21  5577150313   94690
# 22  6117666160   82486
# 23  6290855005   16181
# 24  6391747486   12032
# 25  6775888955   50031
# 26  6962181067  176956
# 27  7007744171  147124
# 28  7086361926   73247
# 29  8053475328  163288
# 30  8253242879   28679
# 31  8378563200   97623
# 32  8583815059   24364
# 33  8792009665   37139
# 34  8877689391  209005

# %%
low.set_index('Id')
# Out:
#              count
# Id
# 1503960366  221170
# 1624580081   80299
# 1644430081   92748
# 1844505072   43687
# 1927972279   26170
# 2022484408  146099
# 2026352035   40713
# 2320127002   37661
# 2347167796  147001
# 2873212765   79639
# 2891001357    6189
# 3372868164   61275
# 3977333714  103967
# 4020332650  184851
# 4057192912   60391
# 4319703577   93847
# 4388161847       0
# 4445114986   64396
# 4558609924   69423
# 4702921684  119151
# 5553957443  100257
# 5577150313   94690
# 6117666160   82486
# 6290855005   16181
# 6391747486   12032
# 6775888955   50031
# 6962181067  176956
# 7007744171  147124
# 7086361926   73247
# 8053475328  163288
# 8253242879   28679
# 8378563200   97623
# 8583815059   24364
# 8792009665   37139
# 8877689391  209005

# %% [markdown]
# ###  this id person is not logged there activity on Id, total steps

# %%
print(low[low['count'] == low['count'].min()])
# Out:
#             Id  count
# 16  4388161847      0

# %% [markdown]
# # 8 . Explore over an internet that how much calories burn is required for a healthy person and find out how many healthy person we have in our dataset

# %%
cal = fitbit.groupby('Id')['Calories'].sum()

# %%
cal
# Out:
# Id
# 1503960366    34128
# 1624580081    25705
# 1644430081    29164
# 1844505072    19391
# 1927972279    27048
# 2022484408    29704
# 2026352035    16266
# 2320127002    18385
# 2347167796    30320
# 2873212765    20349
# 2891001357    18187
# 3372868164    18603
# 3977333714    16777
# 4020332650    98412
# 4057192912    60913
# 4319703577    23931
# 4388161847    14442
# 4445114986    31617
# 4558609924    21962
# 4702921684    42322
# 5553957443    21630
# 5577150313    36303
# 6117666160    20993
# 6290855005    21656
# 6391747486    15868
# 6775888955    24523
# 6962181067    29249
# 7007744171    31525
# 7086361926    26124
# 8053475328    31825
# 8253242879    17556
# 8378563200    40274
# 8583815059    19130
# 8792009665    24884
# 8877689391    41414
# Name: Calories, dtype: int64

# %%
cal = cal.to_frame(name = 'total calaries').reset_index()

# %%
cal.set_index('Id')
# Out:
#             total calaries
# Id
# 1503960366           34128
# 1624580081           25705
# 1644430081           29164
# 1844505072           19391
# 1927972279           27048
# 2022484408           29704
# 2026352035           16266
# 2320127002           18385
# 2347167796           30320
# 2873212765           20349
# 2891001357           18187
# 3372868164           18603
# 3977333714           16777
# 4020332650           98412
# 4057192912           60913
# 4319703577           23931
# 4388161847           14442
# 4445114986           31617
# 4558609924           21962
# 4702921684           42322
# 5553957443           21630
# 5577150313           36303
# 6117666160           20993
# 6290855005           21656
# 6391747486           15868
# 6775888955           24523
# 6962181067           29249
# 7007744171           31525
# 7086361926           26124
# 8053475328           31825
# 8253242879           17556
# 8378563200           40274
# 8583815059           19130
# ...

# %%
# we have almost 19 days data is there in our data set, over an inter net healthy person need to burn the '1166' calorires need to burn
# as per my analysis 19 * 1166 = 22154 calaries need to burn as per fitbit dataset

# %%
cal[cal['total calaries'] >= 22154]
# Out:
#             Id  total calaries
# 0   1503960366           34128
# 1   1624580081           25705
# 2   1644430081           29164
# 4   1927972279           27048
# 5   2022484408           29704
# 8   2347167796           30320
# 13  4020332650           98412
# 14  4057192912           60913
# 15  4319703577           23931
# 17  4445114986           31617
# 19  4702921684           42322
# 21  5577150313           36303
# 25  6775888955           24523
# 26  6962181067           29249
# 27  7007744171           31525
# 28  7086361926           26124
# 29  8053475328           31825
# 31  8378563200           40274
# 33  8792009665           24884
# 34  8877689391           41414

# %% [markdown]
# ### only one person we have healthy in our dataset

# %%
len(cal[cal['total calaries'] >= 22154])
# Out:
# 20

# %%
fitbit.head(10)
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366   2016-03-25       11004           7.11             7.11
# 1  1503960366   2016-03-26       17609          11.55            11.55
# 2  1503960366   2016-03-27       12736           8.53             8.53
# 3  1503960366   2016-03-28       13231           8.93             8.93
# 4  1503960366   2016-03-29       12041           7.85             7.85
# 5  1503960366   2016-03-30       10970           7.16             7.16
# 6  1503960366   2016-03-31       12256           7.86             7.86
# 7  1503960366   2016-04-01       12262           7.87             7.87
# 8  1503960366   2016-04-02       11248           7.25             7.25
# 9  1503960366   2016-04-03       10016           6.37             6.37
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                2.57                      0.46
# ...

# %% [markdown]
# # 9. how many person are not a regular person with respect to activity try to find out those

# %%
active_count=fitbit.groupby('Id')['ActivityDate'].count().sort_values(ascending=False)
active_count
# Out:
# Id
# 4057192912    32
# 4020332650    32
# 1503960366    19
# 1624580081    19
# 2347167796    15
# 4702921684    15
# 4445114986    15
# 6962181067    14
# 2320127002    12
# 4558609924    12
# 8792009665    12
# 8378563200    12
# 8253242879    12
# 7086361926    12
# 7007744171    12
# 2026352035    12
# 5553957443    12
# 8877689391    12
# 1844505072    12
# 2022484408    12
# 2873212765    12
# 3977333714    12
# 1927972279    12
# 4319703577    12
# 8053475328    11
# 5577150313    11
# 6290855005    10
# 1644430081    10
# 6117666160    10
# 3372868164    10
# 6391747486     9
# 6775888955     9
# 2891001357     8
# 8583815059     8
# 4388161847     8
# Name: ActivityDate, dtype: int64

# %%
# I given who's activity count leass than 12 those persons are irregular persons

active_count.index
# Out:
# Int64Index([4057192912, 4020332650, 1503960366, 1624580081, 2347167796,
#             4702921684, 4445114986, 6962181067, 2320127002, 4558609924,
#             8792009665, 8378563200, 8253242879, 7086361926, 7007744171,
#             2026352035, 5553957443, 8877689391, 1844505072, 2022484408,
#             2873212765, 3977333714, 1927972279, 4319703577, 8053475328,
#             5577150313, 6290855005, 1644430081, 6117666160, 3372868164,
#             6391747486, 6775888955, 2891001357, 8583815059, 4388161847],
#            dtype='int64', name='Id')

# %% [markdown]
# # 10 . who is the thired most active person in this dataset find out those in pandas and in sql both .

# %%
active_count = active_count.to_frame(name = 'active_count').reset_index()

# %%
active_count
# Out:
#             Id  active_count
# 0   4057192912            32
# 1   4020332650            32
# 2   1503960366            19
# 3   1624580081            19
# 4   2347167796            15
# 5   4702921684            15
# 6   4445114986            15
# 7   6962181067            14
# 8   2320127002            12
# 9   4558609924            12
# 10  8792009665            12
# 11  8378563200            12
# 12  8253242879            12
# 13  7086361926            12
# 14  7007744171            12
# 15  2026352035            12
# 16  5553957443            12
# 17  8877689391            12
# 18  1844505072            12
# 19  2022484408            12
# 20  2873212765            12
# 21  3977333714            12
# 22  1927972279            12
# 23  4319703577            12
# 24  8053475328            11
# 25  5577150313            11
# 26  6290855005            10
# 27  1644430081            10
# 28  6117666160            10
# 29  3372868164            10
# 30  6391747486             9
# ...

# %%
active_count.set_index('Id')
# Out:
#             active_count
# Id
# 4057192912            32
# 4020332650            32
# 1503960366            19
# 1624580081            19
# 2347167796            15
# 4702921684            15
# 4445114986            15
# 6962181067            14
# 2320127002            12
# 4558609924            12
# 8792009665            12
# 8378563200            12
# 8253242879            12
# 7086361926            12
# 7007744171            12
# 2026352035            12
# 5553957443            12
# 8877689391            12
# 1844505072            12
# 2022484408            12
# 2873212765            12
# 3977333714            12
# 1927972279            12
# 4319703577            12
# 8053475328            11
# 5577150313            11
# 6290855005            10
# 1644430081            10
# 6117666160            10
# 3372868164            10
# 6391747486             9
# 6775888955             9
# 2891001357             8
# 8583815059             8
# 4388161847             8

# %%
print(active_count[active_count['active_count'] == active_count['active_count'].index])
# Out:
#             Id  active_count
# 12  8253242879            12

# %%
nth_row = 2
third_most_active = active_count.iloc[nth_row]
third_most_active
# Out:
# Id              1503960366
# active_count            19
# Name: 2, dtype: int64

# %%
cursor.execute("SELECT Id,count(ActivityDate) FROM fitbit_data group by Id order by 2 DESC limit 1,3 ")

# %%
l1 =[]
for i in cursor.fetchall():
    l1.append(i)
    
print(l1[1])
# Out:
# (1503960366, 19)

# %% [markdown]
# # 11 . who is the 5th most laziest person avilable in dataset find it out

# %%
active_count
# Out:
#             Id  active_count
# 0   4057192912            32
# 1   4020332650            32
# 2   1503960366            19
# 3   1624580081            19
# 4   2347167796            15
# 5   4702921684            15
# 6   4445114986            15
# 7   6962181067            14
# 8   2320127002            12
# 9   4558609924            12
# 10  8792009665            12
# 11  8378563200            12
# 12  8253242879            12
# 13  7086361926            12
# 14  7007744171            12
# 15  2026352035            12
# 16  5553957443            12
# 17  8877689391            12
# 18  1844505072            12
# 19  2022484408            12
# 20  2873212765            12
# 21  3977333714            12
# 22  1927972279            12
# 23  4319703577            12
# 24  8053475328            11
# 25  5577150313            11
# 26  6290855005            10
# 27  1644430081            10
# 28  6117666160            10
# 29  3372868164            10
# 30  6391747486             9
# ...

# %%
nth_row = -5
fifth_most_laziest =active_count.iloc[nth_row]
fifth_most_laziest
# Out:
# Id              6391747486
# active_count             9
# Name: 30, dtype: int64

# %% [markdown]
# # 12 . what is a totla acumulative calories burn for a person find out

# %%
cal = fitbit.groupby('Id')['Calories'].sum()
cal = cal.to_frame(name = 'total calaries').reset_index()
cal.set_index('Id')
# Out:
#             total calaries
# Id
# 1503960366           34128
# 1624580081           25705
# 1644430081           29164
# 1844505072           19391
# 1927972279           27048
# 2022484408           29704
# 2026352035           16266
# 2320127002           18385
# 2347167796           30320
# 2873212765           20349
# 2891001357           18187
# 3372868164           18603
# 3977333714           16777
# 4020332650           98412
# 4057192912           60913
# 4319703577           23931
# 4388161847           14442
# 4445114986           31617
# 4558609924           21962
# 4702921684           42322
# 5553957443           21630
# 5577150313           36303
# 6117666160           20993
# 6290855005           21656
# 6391747486           15868
# 6775888955           24523
# 6962181067           29249
# 7007744171           31525
# 7086361926           26124
# 8053475328           31825
# 8253242879           17556
# 8378563200           40274
# 8583815059           19130
# ...
